# %%
import pandas as pd
df = pd.read_csv("output/generative_output_final.csv")

# %% [markdown]
# Example truncated output:

# %%
print(df.iloc[3]['model_output'])
# Out:
# [' (one token:::LABEL per line)\n                    In:::O\n                    January:::O\n                    2011:::O\n                    he:::O\n                    published:::O\n                    Pendulum:::O\n                    Swing:::O\n                    :::O\n                    which:::O\n                    analyzed:::O\n                    the:::O\n                    2010:::O\n                    midterm:::O\n                    elections:::O\n                    and:::O\n                    the:::O\n                    potential:::O\n                    effect:::O\n                    of:::O\n                    Republican:::O\n                    Party:::O\n                    victories:::O\n                    on:::O\n                    the:::O\n                    2012:::O\n                    presidential:::O\n                    congressional:::O\n                    and:::O\n                    state-level:::O\n                    elections:::O\n        
# ...

# %% [markdown]
# Example code output:

# %%
print(df.iloc[24]['model_output'])
# Out:
# [' \n                    Across:::O\nthese:::O\ndepartments:::O\nthe:::O\ncollege:::O\noffers:::O\n14:::O\nBachelor:::O\nMaster:::O\nand:::O\nDoctoral:::O\ndegrees:::O\nas:::O\nwell:::O\nas:::O\n3:::O\none-year:::O\nCertificates:::O\n(:::O\nWorship:::O\nLeadership:::other-educationaldegree\n,:::O\nBible:::other-educationaldegree\n,:::O\nor:::O\nChristian:::O\nCounseling:::other-educationaldegree\n):::O\n.:::O\nAfter:::O\nthe:::O\n2011:::event-election\nScottish:::O\nParliament:::O\nelection:::event-election\ngave:::O\nthe:::O\nSNP:::O\nan:::O\noverall:::O\nmajority:::O\nin:::O\nthe:::O\nScottish:::O\nParliament:::O\n,:::O\nthe:::O\n2014:::event-election\nScottish:::O\nindependence:::event-election\nreferendum:::event-election\nwas:::O\nheld:::O\non:::O\n18:::O\nSeptember:::O\n.:::O\nThe:::O\npark:::O\nwas:::O\nestablished:::O\nin:::O\n1955:::O\n,:::O\nand:::O\ncovers:::O\nincluding:::O\nthe:::O\nheadwaters:::O\nof:::O\nthe:::O\nWood:::O\nRiver:::location-bodiesofwater\n.:::O\nTrethew
# ...

# %% [markdown]
# Example wrong output format:

# %%
print(df.iloc[29]['model_output'])
# Out:
# [' \n                    Elsewhere in the city, the ::: [O, O, O, O, O, O, O, location-other, location-other, location-other, location-other]\n                    The parish ::: [O, O, O, O, O, location-other, location-other, location-other, location-other, location-other, location-other, location-other, location-other]\n                    Temperature and moisture ::: [O, O, O, O, O, O, O, O, O, other-livingthing, other-livingthing, other-livingthing, other-livingthing, O, O, O, O, O, O, O]\n                    Being a hybrid ::: [O, O, other-livingthing, other-livingthing, other-livingthing, other-livingthing, other-livingthing, other-livingthing, other-livingthing, other-livingthing, other-livingthing, other-livingthing, O, O, O, O, O, O, other-livingthing, other-livingthing, other-livingthing, other-livingthing]\n                    The modern ::: [O, O, O, O, O, location-bodiesofwater, location-bodiesofwater, location-bodiesofwater, location-bodiesofwater, location-bodiesofwater
# ...

# %% [markdown]
# Example copies of own instructions:

# %%
print(df.iloc[37]['model_output'])
# Out:
# [" The output should be in the format of one token:::LABEL per line, nothing else.\n                    For example:\n                    At:::O\n                    the:::O\n                    publishing:::O\n                    house:::O\n                   ,:::O\n                    he:::O\n                    redesigned:::O\n                    the:::O\n                    ``:::O\n                    Combined:::O\n                    Volume:::O\n                    ``:::O\n                   ,:::O\n                    ``:::O\n                    Railway:::O\n                    World:::O\n                    ``:::O\n                    and:::O\n                    helped:::O\n                    to:::O\n                    transform:::O\n                    ``:::Trains:::O\n                    Illustrated:::O\n                    ``:::O\n                    into:::O\n                    ``:::O\n                    Modern:::O\n                    Railways:::O\n                   
# ...

# %% [markdown]
# Example made up labels:

# %%
print(df.iloc[1183]['model_output'])
# Out:
# [" \n                    He:::O\n                    was:::O\n                    chosen:::O\n                    in:::O\n                    the:::O\n                    same:::O\n                    year:::O\n                    president:::O\n                    of:::O\n                    Christ's:::building-hospital\n                    Hospital:::building-hospital\n                    to:::O\n                    which:::O\n                    and:::O\n                    Bethlehem:::building-hospital\n                    Hospital:::building-hospital\n                    he:::O\n                    proved:::O\n                    a:::O\n                    liberal:::O\n                    benefactor:::O\nHe:::O\nwas:::O\nsubsequently:::O\nelected:::O\nand:::O\nbecame:::O\nChairman:::organization-government/governmentagency\nof:::O\nthe:::O\nFinance:::organization-government/governmentagency\nCommittee:::organization-government/governmentagency\nFirst:::O\nelected:::O\nto:::O\nMo
# ...
